# %% [markdown]
# <a href="https://colab.research.google.com/github/sathana495/ML-project/blob/main/placement__prediction1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Tittle : placement _prediction

# %% [markdown]
# *step 1 : Uploading Dataset*

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/dataset/college_student_placement_dataset.csv")
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df.tail()
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 9995                    No                       1                     8
# 9996                    No                       0                     7
# 9997                   Yes                       3                     9
# 9998                    No                       7                     5
# 9999                    No                       3                     5
#
#       Projects_Completed Placement
# 9995                   0       Yes
# 9996                   2        No
# ...

# %%
df.describe()
# Out:
#                  IQ  Prev_Sem_Result          CGPA  Academic_Performance  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      99.471800         7.535673      7.532379              5.546400
# std       15.053101         1.447519      1.470141              2.873477
# min       41.000000         5.000000      4.540000              1.000000
# 25%       89.000000         6.290000      6.290000              3.000000
# 50%       99.000000         7.560000      7.550000              6.000000
# 75%      110.000000         8.790000      8.770000              8.000000
# max      158.000000        10.000000     10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count            10000.000000          10000.000000        10000.000000
# mean                 4.970900              5.561800            2.513400
# std                  3.160103              2.900866            1.715959
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df.isna().sum()
# Out:
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64

# %% [markdown]
# *step 2 : Data preprocessing*

# %%
list1 = ['Internship_Experience','Placement']

# %%
df[list1] = df[list1].replace({'Yes':1,'No':0})
# Out:
# /tmp/ipykernel_3702/220397146.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[list1] = df[list1].replace({'Yes':1,'No':0})

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#    Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                      0                       8                     8
# 1                      0                       7                     8
# 2                      0                       3                     1
# 3                      1                       1                     6
# 4                      0                       8                    10
#
#    Projects_Completed  Placement
# 0                   4          0
# 1                   0          0
# 2                   1          0
# ...

# %%
df['College_ID'] = pd.factorize(df['College_ID'])[0] + 1
df.head()
# Out:
#    College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0           1  107             6.61  6.28                     8
# 1           2   97             5.52  5.37                     8
# 2           3  109             5.36  5.83                     9
# 3           4  122             5.47  5.75                     6
# 4           5   96             7.91  7.69                     7
#
#    Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                      0                       8                     8
# 1                      0                       7                     8
# 2                      0                       3                     1
# 3                      1                       1                     6
# 4                      0                       8                    10
#
#    Projects_Completed  Placement
# 0                   4          0
# 1                   0          0
# 2                   1          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  int64
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  int64
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 781.4 KB

# %% [markdown]
# *step 3 : Data visulaization for batter understanding*

# %%
core = df.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(core,annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.hist(figsize=(10,10),bins=10)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df['CGPA'], bins=50, kde=True, ax=axes[0])
axes[0].set_title('Distribution of CGPA')
axes[0].set_xlabel('CGPA')
axes[0].set_ylabel('Frequency')

sns.histplot(df['Prev_Sem_Result'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Distribution of Previous Semester Result')
axes[1].set_xlabel('Prev_Sem_Result')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Academic_Performance', data=df, palette='viridis')
plt.title('Distribution of Academic Performance')
plt.xlabel('Academic Performance Score')
plt.ylabel('Number of Students')
plt.show()
# Out:
# /tmp/ipykernel_3702/2082108771.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Academic_Performance', data=df, palette='viridis')

# %% [markdown]
# *step 4 : split train & test data*

# %%
x = df.drop('Placement',axis=1)
y = df['Placement']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x
# Out:
#       College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0              1  107             6.61  6.28                     8
# 1              2   97             5.52  5.37                     8
# 2              3  109             5.36  5.83                     9
# 3              4  122             5.47  5.75                     6
# 4              5   96             7.91  7.69                     7
# ...          ...  ...              ...   ...                   ...
# 9995          88  119             8.41  8.29                     4
# 9996          86   70             9.25  9.34                     7
# 9997          59   89             6.08  6.25                     3
# 9998          60  107             8.77  8.92                     3
# 9999          98  109             9.41  9.77                     8
#
#       Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                         0                       8                     8
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Placement, Length: 10000, dtype: int64

# %% [markdown]
# *step 5 : Build a linear regression model*

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
lr_accuracy = accuracy_score(y_test,y_pred)
lr_accuracy*100
# Out:
# 100.0

# %% [markdown]
# *step 6 : build a random forest model*

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rf=RandomForestClassifier()
Rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred= Rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
Rf_accuracy = accuracy_score(y_test,y_pred)
Rf_accuracy*100
# Out:
# 100.0

# %%
Rf_report = classification_report(y_test,y_pred)
Rf_report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      1674\n           1       1.00      1.00      1.00       326\n\n    accuracy                           1.00      2000\n   macro avg       1.00      1.00      1.00      2000\nweighted avg       1.00      1.00      1.00      2000\n'

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Initialize and train the Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(x_train, y_train)

# Make predictions on the test set
y_pred_dt = dt_model.predict(x_test)

# Evaluate the Decision Tree model
dt_accuracy = accuracy_score(y_test, y_pred_dt)
dt_conf_matrix = confusion_matrix(y_test, y_pred_dt)
dt_class_report = classification_report(y_test, y_pred_dt)

print(f"Decision Tree Accuracy: {dt_accuracy*100:.2f}%")
print("\nDecision Tree Confusion Matrix:\n", dt_conf_matrix)
print("\nDecision Tree Classification Report:\n", dt_class_report)
# Out:
# Decision Tree Accuracy: 100.00%
#
# Decision Tree Confusion Matrix:
#  [[1674    0]
#  [   0  326]]
#
# Decision Tree Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1674
#            1       1.00      1.00      1.00       326
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000
